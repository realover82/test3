# %%
#필요한 패키지를 import
import matplotlib.pyplot as plt
import seaborn as sns

#jupyter에서 matplotlib을 사용해 만든 graph를 화면에 표시하기 위해 필요
# %matplotlib inline 

#아래는 한글을 사용할 때 깨지는 문제에 대한 해결
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

#그래프의 축 등에서 음수를 표시할 때 minus sign이 깨지는 것 해결
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False

# %%
tit = sns.load_dataset('titanic')
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.barplot(x="sex", y="survived", hue="sex", data=tit)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
sns.countplot(x='class', data=tit)
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(x='sex', data=tit)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
# sns.barplot(x='sex', y='servived', data=tit)
# sns.barplot(x="sex", y="servived", data=tit)
# sns.barplot(x="sex", y="servived", data=tit)
sns.barplot(x="sex", y="survived", hue="sex", data=tit)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
# sns.barplot(x="class", y='servived', data=tit)
sns.barplot(x="sex", y="survived", hue="sex", data=tit)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
# sns.histplot(x="age", bins=20)
sns.barplot(x="sex", y="survived", hue="sex", data=tit)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
plt.figure(figsize=(8,3))
sns.histplot(x="age",bins=20, data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# plt.figure(figsize=(8,3))
sns.histplot(x="age",bins=20, kde=True, data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# plt.figure(figsize=(8,3))
sns.histplot(x="fare",bins=30, kde=True, data=tit)
# Out:
# <AxesSubplot:xlabel='fare', ylabel='Count'>

# %%
# plt.figure(figsize=(8,3))
sns.histplot(x="age",bins=30, kde=True, hue="survived", data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
# plt.figure(figsize=(8,3))
# sns.histplot(x="age",bins=30, kde=True, hue="survived", data=tit)
sns.histplot(x="age",bins=30, kde=True, stat="percent", data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Percent'>

# %%
# stat="density"

sns.histplot(x="age",bins=30, kde=True, stat="density", data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.histplot(x="age",bins=30, kde=True, hue="survived", multiple="dodge", stat="density", data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.histplot(x="age",bins=30, kde=True, hue="sex", multiple="dodge", stat="density", data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.histplot(x="age",bins=30, kde=True, hue="class", multiple="dodge", stat="density", data=tit)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tit)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44836/2164875560.py in <cell line: 1>()
# ----> 1 sns.barplot(x="day", y="total_bill", hue="sex", data=tit)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %%
sns.barplot(x="class", y="survived", data=tit)
# sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.barplot(x="class", y="survived", hue="sex", data=tit)
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
sns.boxplot(x="class", y="age", hue="sex", data=tit)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="total_bill", y="day", data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
iris = sns.load_dataset("iris")
sns.pairplot(iris)

# %%
corr=tit.corr()
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
corr=tit.corr()
sns.heatmap(corr, annot=True, fmt=".1f")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x="day", y="total_bill", hue="smoker" data=tips, color_palette("flare", as_cmap=True))
# 팔렛트
# Out:
#   File "C:\Users\ADMIN\AppData\Local\Temp/ipykernel_44836/643741003.py", line 1
#     sns.barplot(x="day", y="total_bill", hue="smoker" data=tips, color_palette("flare", as_cmap=True))
#                                                       ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(hue="smoker", data=tips)

# %%
flights= sns.load_dataset("flights")
print(flights.head(5))
flights=flights.pivot("month","year","passengers")
print(flights.head(5))
plt.figure(figsize=(10,10))

ax=sns.heatmap(flights,annot=True, fmt="d")
# flights.head(5)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
import pandas as pd
df=pd.read_csv("2022-03-q.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_44836/1426730093.py in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("2022-03-q.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
figure, ((ax1,ax2,ax3), (ax4,ax5,ax6))=plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(20,10)
sns.countplot(data=tit, x="class", hue="survived", ax=ax1)
sns.countplot(data=tit, x="sex", hue="survived", ax=ax2)
sns.barplot(x='class', y='survived', data=tit, ax=ax3)
sns.heatmap(corr, annot=True, fmt=".1f", ax=ax4)
sns.boxplot(x='class', y='survived', data=tit, ax=ax5)
sns.boxplot(x='class', y='age',hue='sex', data=tit, ax=ax6)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.barplot(x='class', y='survived', data=tit, ax=ax3)
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %%
import pandas as pd
df = pd.DataFrame(tit)
df.to_csv('test.csv',index=False)

# %%
df = pd.DataFrame(data)
