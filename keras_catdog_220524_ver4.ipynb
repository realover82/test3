# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
cd ..
# Out:
# C:\Users\ADMIN\Desktop

# %%
cd ..
# Out:
# C:\Users\ADMIN

# %%
cd downloads
# Out:
# C:\Users\ADMIN\downloads

# %%
image_size = (180, 180)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "catdog/train/train",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "catdog/train/train",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 25000 files belonging to 2 classes.
# Using 20000 files for training.
# Found 25000 files belonging to 2 classes.
# Using 5000 files for validation.

# %%
import os
import pandas as pd 

filenames = os.listdir("catdog/train/train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dogs':
        categories.append(1)
    else:
        categories.append(0)

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df['filename'].value_counts().plot.bar()
# df['category'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %%
data_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
    ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
from keras.models import Sequential

# %%
model = Sequential()

# %%
from keras.layers import Dense, Activation, Flatten

# %%
model.add(Flatten())

# %%
model.add(Flatten(input_shape = (32,32)))

# %%
model = classicalModel(input_shape=(batch_size, IM_WIDTH, IM_HEIGHT))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 model = classicalModel(input_shape=(batch_size, IM_WIDTH, IM_HEIGHT))
#
# NameError: name 'classicalModel' is not defined

# %%
model = ClassicalModel(input_shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 model = ClassicalModel(input_shape)
#
# NameError: name 'ClassicalModel' is not defined

# %%
model = Sequential([
    Dense(32, input_shape=(784,)),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])

# %%
layer = tf.keras.layers.Dense(10, input_shape=(None, 5))

# %%
augmented_train_ds = train_ds.map(
  lambda x, y: (data_augmentation(x, training=True), y))

# %%
# train_ds = train_ds.prefetch(buffer_size=32)
# val_ds = val_ds.prefetch(buffer_size=32)

# %%
from tensorflow.keras.utils import plot_model

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    # Image augmentation block
    x = data_augmentation(inputs)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(x)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=2)
# tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model = tf.keras.models.load_model('save_at3_2.h5')

# %%
epochs = 2

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at4_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
# model.fit(
#     train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
# )
# Out:
# Epoch 1/2
# 454/625 [====================>.........] - ETA: 7:20 - loss: 0.2449 - accuracy: 0.8973
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [26], in <cell line: 11>()
#       3 callbacks = [
#       4     keras.callbacks.ModelCheckpoint("save_at4_{epoch}.h5"),
#       5 ]
#       6 model.compile(
#       7     optimizer=keras.optimizers.Adam(1e-3),
#       8     loss="binary_crossentropy",
#       9     metrics=["accuracy"],
#      10 )
# ---> 11 model.fit(
#      12     train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
#      13 )
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ...

# %%
history = model.fit(train_ds, 
                    epochs=epochs, 
                    validation_data=val_ds)  #오류난다.
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 history = model.fit(train_ds,
#       2                     epochs=epochs,
#       3                     validation_data=val_ds)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ...

# %%
img = keras.preprocessing.image.load_img(
    "catdog/test1/test1/6779.jpg", target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions[0]
print(
    "This image is %.2f percent cat and %.2f percent dog."
    % (100 * (1 - score), 100 * score)
)
# Out:
# 1/1 [==============================] - 0s 474ms/step
# This image is 8.71 percent cat and 91.29 percent dog.

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
Generator_cnn = ImageDataGenerator(rescale=1/255.)

# %%
test_gen_cnn = Generator_cnn.flow_from_directory ('catdog', target_size=(64, 64),
                                         batch_size=32, classes=['test3-1'])
# Out:
# Found 4 images belonging to 1 classes.

# %%
score = model.evaluate(test_gen_cnn, verbose=0)
print(f'Test loss: {score[0]:.3f}')
print(f'Test accuracy: {score[1]:.3f}')
# Out:
# Test loss: 2.461
# Test accuracy: 0.000

# %%
import numpy as np

x_tests, y_tests = [], []
for i in range(len(test_gen_cnn)):
  x_test, y_test = next(test_gen_cnn)
  x_tests.append(x_test)
  y_tests.append(y_test)

x_test = np.concatenate(x_tests, axis=0)
y_test = np.concatenate(y_tests, axis=0)

print(x_test.shape)
print(y_test.shape)
# Out:
# (4, 64, 64, 3)
# (4, 1)

# %%
pred_cnn = model.predict(x_test[:4])

for i in range(4):
   plt.imshow(x_test[i])
   plt.title(pred_cnn[i])
   plt.show()
# Out:
# 1/1 [==============================] - 0s 252ms/step
# C:\Users\ADMIN\anaconda3\lib\site-packages\matplotlib\text.py:1223: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
epochs = 2

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at3_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
history = model.fit(train_gen_cnn, 
                    epochs=epochs, 
                    validation_data=val_gen_cnn)
# Out:
# Epoch 1/2
# 625/625 [==============================] - 1732s 3s/step - loss: 0.3277 - accuracy: 0.8563 - val_loss: 0.4398 - val_accuracy: 0.7980
# Epoch 2/2
# 625/625 [==============================] - 1698s 3s/step - loss: 0.2877 - accuracy: 0.8804 - val_loss: 0.2596 - val_accuracy: 0.8898
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 14>()
#       6 model.compile(
#       7     optimizer=keras.optimizers.Adam(1e-3),
#       8     loss="binary_crossentropy",
#       9     metrics=["accuracy"],
#      10 )
#      11 model.fit(
#      12     train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
#      13 )
# ---> 14 history = model_cnn.fit(train_gen_cnn,
#      15                     epochs=epochs,
#      16                     validation_data=val_gen_cnn)
#
# NameError: name 'model_cnn' is not defined

# %%
epochs = 2

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at3_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Epoch 1/2
# 215/625 [=========>....................] - ETA: 18:09 - loss: 0.2573 - accuracy: 0.8904
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [38], in <cell line: 11>()
#       3 callbacks = [
#       4     keras.callbacks.ModelCheckpoint("save_at3_{epoch}.h5"),
#       5 ]
#       6 model.compile(
#       7     optimizer=keras.optimizers.Adam(1e-3),
#       8     loss="binary_crossentropy",
#       9     metrics=["accuracy"],
#      10 )
# ---> 11 model.fit(
#      12     train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
#      13 )
#      14 history = model.fit(train_ds,
#      15                     epochs=epochs,
#      16                     validation_data=val_ds)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
# ...

# %%
import tensorflow as tf

# %%
tf.reshape(x, [-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 tf.reshape(x, [-1])
#
# NameError: name 'x' is not defined

# %%
history = model.fit(train_ds, 
                    epochs=epochs, 
                    validation_data=val_ds,)
# Out:
# Epoch 1/2
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 history = model.fit(train_ds,
#       2                     epochs=epochs,
#       3                     validation_data=val_ds,)
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 4>()
#       1 import matplotlib.pyplot as plt
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 4 loss = history['loss']
#       5 val_loss = history['val_loss']
#       7 epochs = range(1, len(loss) + 1)
#
# NameError: name 'history' is not defined

# %%
# train_ds = train_ds.prefetch(buffer_size=32)
# val_ds = val_ds.prefetch(buffer_size=32)
